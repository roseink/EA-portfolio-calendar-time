# %%
import boto3
import pandas as pd
import numpy as np 
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import time
import exchange_calendars as xcals

s3 = boto3.resource('s3')
client = boto3.client('s3')

# Need to put these elsewhere and create profile via command prompt/Terminal 
aws_access_key = "AKIAXYJUIRVOL5AAJBOC"
aws_secret_access_key = "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"

download_dir = "C://Users/clj585/Downloads/"

client = boto3.client('s3')
client.download_file(
    "us-equity-cumulative-adjustment-secid-all", "41/41278.csv",
    download_dir+"41278.csv", ExtraArgs={'RequestPayer': 'requester'}
)

altria = pd.read_csv(download_dir+"41278.csv")
altria
# Out:
#     SecId Ticker  EffectiveDate  CumulativeFactorPriceBackward  \
# 0   41278     MO       20070103                       1.000000
# 1   41278     MO       20070313                       0.311830
# 2   41278     MO       20070402                       0.314956
# 3   41278     MO       20070613                       0.419535
# 4   41278     MO       20070912                       0.423703
# ..    ...    ...            ...                            ...
# 60  41278     MO       20210614                       0.913097
# 61  41278     MO       20210914                       0.929156
# 62  41278     MO       20211222                       0.946160
# 63  41278     MO       20220324                       0.964328
# 64  41278     MO       20220614                       0.980916
#
#     CumulativeFactorPriceForward  CumulativeFactorVolumeBackward  \
# 0                       1.000000                             1.0
# 1                       0.990076                             1.0
# ...

# %%
import boto3
import pandas as pd
import numpy as np 
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import time
import exchange_calendars as xcals

s3 = boto3.resource('s3')
client = boto3.client('s3')

# Need to put these elsewhere and create profile via command prompt/Terminal 
aws_access_key = "AKIAXYJUIRVOL5AAJBOC"
aws_secret_access_key = "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"

download_dir = "C://Users/clj585/Downloads/"

    
# Create string to pass in for data bucket 
#stringpass = 'us-equity-daily-ohlc-primary-secid-all'+'/'+str(41278)[0:2]+'/'
#print(stringpass)
    
# Create CSV name for passing in 
#csvname = str(41278)+".csv"
#print(csvname)
    
# Download with parameters defined above 
client.download_file('us-equity-daily-ohlc-primary-secid-all/41/', '41278.csv',
                    download_dir+'41278.csv',
                    ExtraArgs={'RequestPayer': 'requester'})
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20488/3434982675.py in <module>
#      26
#      27 # Download with parameters defined above
# ---> 28 client.download_file('s3://us-equity-daily-ohlc-primary-secid-all/41/', '41278.csv',
#      29                     download_dir+'41278.csv',
#      30                     ExtraArgs={'RequestPayer': 'requester'})
#
# ~\AppData\Roaming\Python\Python38\site-packages\boto3\s3\inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     188     """
#     189     with S3Transfer(self, Config) as transfer:
# --> 190         return transfer.download_file(
#     191             bucket=Bucket,
#     192             key=Key,
#
# ~\AppData\Roaming\Python\Python38\site-packages\boto3\s3\transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
# ...

# %%
import boto3
import pandas as pd
import numpy as np 
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import time
import exchange_calendars as xcals

s3 = boto3.resource('s3')
client = boto3.client('s3')

# Need to put these elsewhere and create profile via command prompt/Terminal 
aws_access_key = "AKIAXYJUIRVOL5AAJBOC"
aws_secret_access_key = "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"

# Until date set / algoseek doesn't have today's data yet!
hist_to_dt = (datetime.today()-relativedelta(days=1)).strftime("%m/%d/%y")

# Download directory set 
download_dir = "C://Users/clj585/OneDrive - Northwestern University/data_feeds/algoseek/Data/"

# Download and generate a list of holidays
nys = xcals.get_calendar("XNYS", side='left')
nys = nys.schedule.loc["2007-01-01":hist_to_dt]
nys.reset_index(inplace=True)
tradedays = list(nys['index'])

# Loop over trade days generated above
for i in tradedays:
    print(str(datetime.strftime(i, "%Y%m%d")))
    yr = str(i.year)
    
    # Create string to pass in for data bucket 
    stringpass = 'us-equity-daily-ohlc-primary-tradedate-'+str(yr)
    print(stringpass)
    
    # Create CSV name for passing in 
    csvname = str(datetime.strftime(i, "%Y%m%d"))+".csv"
    print(csvname)
    
    # Download with parameters defined above 
    client.download_file(stringpass, csvname,
                         download_dir+csvname,
                         ExtraArgs={'RequestPayer': 'requester'})

# %%
# Imported libraries 
import boto3
import pandas as pd 
import numpy as np
from datetime import datetime, timedelta, date
from dateutil.relativedelta import relativedelta
import time
import exchange_calendars as xcals
import sqlite3
import glob, os

# Have to join all daily factors files together 
onedrive_pth = "C://Users/clj585/OneDrive - Northwestern University/"
factors_pth = "data_feeds/algoseek/Data/temp_daily_adj_factors/"

os.chdir(onedrive_pth+factors_pth)

list_daily_files = []

csv_files = glob.glob("*.csv")
for fname in csv_files:
    print(fname)
    temp_df = pd.read_csv(os.path.join(fname))
    list_daily_files.append(temp_df)
    
fac_df = pd.concat(list_daily_files)
# Out:
# 20070103.csv
# 20070104.csv
# 20070105.csv
# 20070108.csv
# 20070109.csv
# 20070110.csv
# 20070111.csv
# 20070112.csv
# 20070116.csv
# 20070117.csv
# 20070118.csv
# 20070119.csv
# 20070122.csv
# 20070123.csv
# 20070124.csv
# 20070125.csv
# 20070126.csv
# 20070129.csv
# 20070130.csv
# 20070131.csv
# 20070201.csv
# 20070202.csv
# 20070205.csv
# 20070206.csv
# 20070207.csv
# 20070208.csv
# 20070209.csv
# 20070212.csv
# 20070213.csv
# 20070214.csv
# 20070215.csv
# 20070216.csv
# 20070220.csv
# 20070221.csv
# 20070222.csv
# 20070223.csv
# 20070226.csv
# 20070227.csv
# 20070228.csv
# 20070301.csv
# 20070302.csv
# 20070305.csv
# 20070306.csv
# 20070307.csv
# 20070308.csv
# 20070309.csv
# 20070312.csv
# 20070313.csv
# 20070314.csv
# 20070315.csv
# 20070316.csv
# 20070319.csv
# 20070320.csv
# 20070321.csv
# 20070322.csv
# 20070323.csv
# 20070326.csv
# 20070327.csv
# 20070328.csv
# 20070329.csv
# 20070330.csv
# 20070402.csv
# 20070403.csv
# 20070404.csv
# 20070405.csv
# 20070409.csv
# ...

# %%
fac_df = fac_df.sort_values(by=["SecId", 'EffectiveDate'])
fac_df
# Out:
#           SecId Ticker  EffectiveDate  CumulativeFactorPriceBackward  \
# 0          2234    SLF       20070103                       1.000000
# 0          2234    SLF       20070216                       0.522915
# 0          2234    SLF       20070521                       0.526101
# 0          2234    SLF       20070820                       0.529390
# 0          2234    SLF       20071119                       0.533046
# ..          ...    ...            ...                            ...
# 87   1000422074   AWIw       20160317                       1.000000
# 120  1000640750   VMWw       20211028                       1.000000
# 28   1001106115  IILGV       20160411                       1.000000
# 199  1004513431   WRKw       20160502                       1.000000
# 41   1004597098  RACEw       20160104                       1.000000
#
#      CumulativeFactorPriceForward  CumulativeFactorVolumeBackward  \
# 0                        1.000000                             1.0
# ...

# %%
fac_df[fac_df['Ticker']=="TSLA"]
# Out:
#       SecId Ticker  EffectiveDate  CumulativeFactorPriceBackward  \
# 63  1914754   TSLA       20100629                            1.0
# 69  1914754   TSLA       20200831                            0.2
#
#     CumulativeFactorPriceForward  CumulativeFactorVolumeBackward  \
# 63                           1.0                             1.0
# 69                           0.2                             0.2
#
#     CumulativeFactorVolumeForward AdjustmentReason EventType
# 63                            1.0            START     START
# 69                            0.2        ScriptDiv       DIV

# %%
fac_df[fac_df['Ticker']=="MO"]
# Out:
#       SecId Ticker  EffectiveDate  CumulativeFactorPriceBackward  \
# 2739  41278     MO       20070103                       1.000000
# 60    41278     MO       20070313                       0.317897
# 7     41278     MO       20070402                       0.321083
# 91    41278     MO       20070613                       0.427697
# 79    41278     MO       20070912                       0.431946
# ...     ...    ...            ...                            ...
# 8     41278     MO       20210324                       0.915013
# 29    41278     MO       20210614                       0.930862
# 30    41278     MO       20210914                       0.947233
# 7     41278     MO       20211222                       0.964567
# 12    41278     MO       20220324                       0.983089
#
#       CumulativeFactorPriceForward  CumulativeFactorVolumeBackward  \
# 2739                      1.000000                             1.0
# ...
