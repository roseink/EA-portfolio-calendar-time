# %%
#%pip install psycopg2
#%pip install pandas_market_calendars
from io import StringIO
import numpy as np
import gc
from IPython import get_ipython
get_ipython().magic('reset -sf')
import polygon
from datetime import date
import pandas as pd
import pytz
import pandas_market_calendars as mcal
import os
import gc
from sqlalchemy import create_engine
import psycopg2

gc.collect()
# Out:
# C:\Users\Matt_Home\AppData\Local\Temp\ipykernel_63408\257911429.py:7: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('reset -sf')
# 0

# %%
conn_string = 'postgresql://postgres:4989@localhost/Price_Data'
param_dic = {
    "host": "localhost",
    "database": "Price_Data",
    "user": "postgres",
    "password": "4989"
}

# %%
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1)
    print("Connection successful")
    return conn

# %%
db = create_engine(conn_string)
conn = db.connect()

# %%
import boto3

s3 = boto3.resource('s3')

client = boto3.client('s3')

client.download_file(

'us-equity-master-sec-file', 'equity_security_master.csv',

r'D:\OneDrive - Northwestern University\My files\data_feeds\algoseek\Data\equity_security_master.csv', ExtraArgs={'RequestPayer': 'requester'})

# %%
header_list = ["SecId", "Tickers", "TickersStartToEndDate","Name","NameStartToEndDate","ISIN","ISINStartToEndDate","ListStatus",
"SecurityDescription","USIdentifierStartToEndDate","PrimaryExchange","PrimaryExchangeStartToEndDate",
"SEDOL","Sic","Sector","Industry","FIGI"]
df=pd.read_csv(r'D:\OneDrive - Northwestern University\My files\data_feeds\algoseek\Data\equity_security_master.csv',sep=',', names=header_list)
df.head(10)
# Out:
#          SecId                              Tickers  \
# SecId  Tickers                TickersStartToEndDate
# 2234       SLF                    20070103:29991231
# 9470     ASTSF                    20070103:20080530
# 10729     PGLA                    20070103:20100701
# 11019     CTTY                    20070103:20070824
# 11895      SFM                    20070103:20080522
# 18636      NTB                    20160915:29991231
# 18665      TNP                    20070103:29991231
# 18679   ACE;CB  20070103:20160114;20160115:29991231
# 19690     LOGI                    20070103:29991231
#
#                                    TickersStartToEndDate  \
# SecId                                               Name
# 2234                            Sun Life Financial, Inc.
# 9470                                            ASE Test
# 10729  Progen Industries Ltd.;Progen Pharmaceuticals ...
# 11019                                        Catuity Inc
# ...

# %%
df.to_sql('algo_sec_master', con=conn, if_exists='replace', index=False)
# Out:
# 326

# %%
#ticker_to_secid_lookup.csv
client.download_file(
'us-equity-daily-ohlc-primary-tradedate-2022', '20220104.csv',

r'D:\OneDrive - Northwestern University\My files\data_feeds\algoseek\Data\20220104.csv', ExtraArgs={'RequestPayer': 'requester'})

# %%
df=pd.read_csv(r'D:\OneDrive - Northwestern University\My files\data_feeds\algoseek\ticker_to_secid_lookup.csv',sep=',')
df.to_sql('algo_ticker_to_secid', con=conn, if_exists='replace', index=False)
# Out:
# 846
